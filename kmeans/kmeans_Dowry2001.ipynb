# %%
import pandas as pd
import numpy as np
df = pd.read_csv('mencoded2001.csv')
# df     

#three clusters _(centroidsspecific)
c1 = df['Dowry_Deaths'].min()
c2 = df['Dowry_Deaths'].max()
c3 = df['Dowry_Deaths'].max()/2

# %%
length = len(df['Dowry_Deaths'])
keyss = range(length)
valuess = [None] * length

# %%
lclust_values = dict( zip(keyss,valuess))
mclust_values = dict( zip(keyss,valuess))
hclust_values = dict( zip(keyss,valuess))

# %%
#calculating distance between the centroids and data
i=0
lclust = 0
hclust = 0
mclust = 0
# print(length)
for i in range(length):
    a = abs(df.Dowry_Deaths[i]-c1)
    b = abs(df.Dowry_Deaths[i]-c2)
    c = abs(df.Dowry_Deaths[i]-c3)
    #the one with the minimum distance will be considered 
    val = min(a,b,c) 
    if val == a:
        lclust = df.Dowry_Deaths[i]
        lclust_values[i] = lclust
    elif val == b:
        hclust = df.Dowry_Deaths[i]
        hclust_values[i] = hclust
    else:
        mclust = df.Dowry_Deaths[i]
        mclust_values[i] = mclust
# print(lclust_values)
# print(hclust_values)
# print(mclust_values)

# %%
l_indexes = [k for k in lclust_values.keys() if lclust_values[k]!=None]
m_indexes = [k for k in mclust_values.keys() if mclust_values[k]!=None]
h_indexes = [k for k in hclust_values.keys() if hclust_values[k]!=None]

# %%
L_index = []
for i in range(len(l_indexes)):
    l_indexes[i] = int(l_indexes[i])
    L_index.append(l_indexes[i])

# %%
# L_index

# %%
M_index = []
for i in range(len(m_indexes)):
    m_indexes[i] = int(m_indexes[i])
    M_index.append(m_indexes[i])

# %%
# M_index

# %%
H_index = []
for i in range(len(h_indexes)):
    h_indexes[i] = int(h_indexes[i])
    H_index.append(h_indexes[i])

# %%
# H_index

# %%
for i in H_index:
    print('STATE: '+ str(df['STATE/UT'][i])+'\t\t\t\t'+'DISTRICT: '+str(df['DISTRICT'][i]))
# Out:
# STATE: BIHAR				DISTRICT: MUZAFFARPUR
# STATE: BIHAR				DISTRICT: PATNA
# STATE: UTTAR PRADESH				DISTRICT: ETAH
# STATE: UTTAR PRADESH				DISTRICT: KHIRI
# STATE: UTTAR PRADESH				DISTRICT: SITAPUR

# %%
for i in M_index:
    print('STATE: '+ str(df['STATE/UT'][i])+'\t\t\t\t'+'DISTRICT: '+str(df['DISTRICT'][i]))
# Out:
# STATE: ANDHRA PRADESH				DISTRICT: HYDERABAD CITY
# STATE: ANDHRA PRADESH				DISTRICT: KARIMNAGAR
# STATE: ANDHRA PRADESH				DISTRICT: MEDAK
# STATE: ANDHRA PRADESH				DISTRICT: NALGONDA
# STATE: ANDHRA PRADESH				DISTRICT: RANGA REDDY
# STATE: ANDHRA PRADESH				DISTRICT: WARANGAL
# STATE: BIHAR				DISTRICT: AURANGABAD
# STATE: BIHAR				DISTRICT: BHOJPUR
# STATE: BIHAR				DISTRICT: DARBHANGA
# STATE: BIHAR				DISTRICT: GAYA
# STATE: BIHAR				DISTRICT: JEHANABAD
# STATE: BIHAR				DISTRICT: MOTIHARI
# STATE: BIHAR				DISTRICT: NALANDA
# STATE: BIHAR				DISTRICT: ROHTAS
# STATE: BIHAR				DISTRICT: SARAN
# STATE: BIHAR				DISTRICT: SIWAN
# STATE: BIHAR				DISTRICT: VAISHALI
# STATE: HARYANA				DISTRICT: BHIWANI
# STATE: HARYANA				DISTRICT: HISSAR
# STATE: JHARKHAND				DISTRICT: BOKARO
# STATE: JHARKHAND				DISTRICT: DHANBAD
# STATE: JHARKHAND				DISTRICT: GIRIDIH
# STATE: JHARKHAND				DISTRICT: HAZARIBAGH
# STATE: KARNATAKA				DISTRICT: BANGALORE COMMR.
# STATE: KARNATAKA				DISTRICT: BANGALORE RURAL
# STATE: KARNATAKA				DISTRICT: TUMKUR
# STATE: MADHYA PRADESH				DISTRICT: BHIND
# STATE: MADHYA PRADESH				DISTRICT: DAMOH
# STATE: MADHYA PRADESH				DISTRICT: DHAR
# STATE: MADHYA PRADESH				DISTRICT: INDORE
# STATE: MADHYA PRADESH				DISTRICT: JABALPUR
# STATE: MADHYA PRADESH				DISTRICT: MORENA
# STATE: MADHYA PRADESH				DISTRICT: SAGAR
# STATE: MADHYA PRADESH				DISTRICT: SIDHI
# STATE: MAHARASHTRA				DISTRICT: BULDHANA
# STATE: MAHARASHTRA				DISTRICT: LATUR
# STATE: ODISHA				DISTRICT: BALASORE
# STATE: ODISHA				DISTRICT: BHADRAK
# STATE: ODISHA				DISTRICT: CUTTACK
# STATE: ODISHA				DISTRICT: KENDRAPARA
# STATE: ODISHA				DISTRICT: PURI
# STATE: RAJASTHAN				DISTRICT: ALWAR
# STATE: RAJASTHAN				DISTRICT: BHARATPUR
# STATE: RAJASTHAN				DISTRICT: JAIPUR
# STATE: UTTAR PRADESH				DISTRICT: AGRA
# STATE: UTTAR PRADESH				DISTRICT: ALIGARH
# STATE: UTTAR PRADESH				DISTRICT: ALLAHABAD
# STATE: UTTAR PRADESH				DISTRICT: AZAMGARH
# STATE: UTTAR PRADESH				DISTRICT: BADAUN
# STATE: UTTAR PRADESH				DISTRICT: BARABANKI
# STATE: UTTAR PRADESH				DISTRICT: BAREILLY
# STATE: UTTAR PRADESH				DISTRICT: BIJNOR
# STATE: UTTAR PRADESH				DISTRICT: BULANDSHAHAR
# STATE: UTTAR PRADESH				DISTRICT: DEORIA
# STATE: UTTAR PRADESH				DISTRICT: ETAWAH
# STATE: UTTAR PRADESH				DISTRICT: FATEHPUR
# STATE: UTTAR PRADESH				DISTRICT: FIROZABAD
# STATE: UTTAR PRADESH				DISTRICT: GHAZIABAD
# STATE: UTTAR PRADESH				DISTRICT: GONDA
# STATE: UTTAR PRADESH				DISTRICT: HARDOI
# STATE: UTTAR PRADESH				DISTRICT: HATHRAS
# STATE: UTTAR PRADESH				DISTRICT: JALAUN
# STATE: UTTAR PRADESH				DISTRICT: JAUNPUR
# STATE: UTTAR PRADESH				DISTRICT: JHANSI
# STATE: UTTAR PRADESH				DISTRICT: KANPUR DEHAT
# STATE: UTTAR PRADESH				DISTRICT: KANPUR NAGAR
# STATE: UTTAR PRADESH				DISTRICT: KAUSHAMBI
# STATE: UTTAR PRADESH				DISTRICT: LUCKNOW
# STATE: UTTAR PRADESH				DISTRICT: MAINPURI
# STATE: UTTAR PRADESH				DISTRICT: MEERUT
# STATE: UTTAR PRADESH				DISTRICT: MIRZAPUR
# STATE: UTTAR PRADESH				DISTRICT: MORADABAD
# STATE: UTTAR PRADESH				DISTRICT: MUZAFFARNAGAR
# STATE: UTTAR PRADESH				DISTRICT: PILIBHIT
# STATE: UTTAR PRADESH				DISTRICT: PRATAPGARH
# STATE: UTTAR PRADESH				DISTRICT: RAIBAREILLY
# STATE: UTTAR PRADESH				DISTRICT: SHAHJAHANPUR
# STATE: UTTAR PRADESH				DISTRICT: SULTANPUR
# STATE: UTTAR PRADESH				DISTRICT: UNNAO
# STATE: UTTAR PRADESH				DISTRICT: VARANASI
# STATE: WEST BENGAL				DISTRICT: 24 PARGANAS NORTH
# STATE: WEST BENGAL				DISTRICT: 24 PARGANAS SOUTH
# STATE: WEST BENGAL				DISTRICT: BURDWAN
# STATE: WEST BENGAL				DISTRICT: MIDNAPUR
# STATE: DELHI				DISTRICT: NORTH WEST

# %%
for i in L_index:
    print('STATE: '+ str(df['STATE/UT'][i])+'\t\t\t'+'DISTRICT: '+str(df['DISTRICT'][i]))
# Out:
# STATE: ANDHRA PRADESH			DISTRICT: ADILABAD
# STATE: ANDHRA PRADESH			DISTRICT: ANANTAPUR
# STATE: ANDHRA PRADESH			DISTRICT: CHITTOOR
# STATE: ANDHRA PRADESH			DISTRICT: CUDDAPAH
# STATE: ANDHRA PRADESH			DISTRICT: EAST GODAVARI
# STATE: ANDHRA PRADESH			DISTRICT: GUNTAKAL RLY.
# STATE: ANDHRA PRADESH			DISTRICT: GUNTUR
# STATE: ANDHRA PRADESH			DISTRICT: KHAMMAM
# STATE: ANDHRA PRADESH			DISTRICT: KRISHNA
# STATE: ANDHRA PRADESH			DISTRICT: KURNOOL
# STATE: ANDHRA PRADESH			DISTRICT: MAHABOOBNAGAR
# STATE: ANDHRA PRADESH			DISTRICT: NELLORE
# STATE: ANDHRA PRADESH			DISTRICT: NIZAMABAD
# STATE: ANDHRA PRADESH			DISTRICT: PRAKASHAM
# STATE: ANDHRA PRADESH			DISTRICT: SECUNDERABAD RLY.
# STATE: ANDHRA PRADESH			DISTRICT: SRIKAKULAM
# STATE: ANDHRA PRADESH			DISTRICT: VIJAYAWADA
# STATE: ANDHRA PRADESH			DISTRICT: VIJAYAWADA RLY.
# STATE: ANDHRA PRADESH			DISTRICT: VISAKHA RURAL
# STATE: ANDHRA PRADESH			DISTRICT: VISAKHAPATNAM
# STATE: ANDHRA PRADESH			DISTRICT: VIZIANAGARAM
# STATE: ANDHRA PRADESH			DISTRICT: WEST GODAVARI
# STATE: ARUNACHAL PRADESH			DISTRICT: CHANGLANG
# STATE: ARUNACHAL PRADESH			DISTRICT: DIBANG VALLEY
# STATE: ARUNACHAL PRADESH			DISTRICT: KAMENG EAST
# STATE: ARUNACHAL PRADESH			DISTRICT: KAMENG WEST
# STATE: ARUNACHAL PRADESH			DISTRICT: LOHIT
# STATE: ARUNACHAL PRADESH			DISTRICT: PAPUM PARE
# STATE: ARUNACHAL PRADESH			DISTRICT: SIANG EAST
# STATE: ARUNACHAL PRADESH			DISTRICT: SIANG UPPER
# STATE: ARUNACHAL PRADESH			DISTRICT: SIANG WEST
# STATE: ARUNACHAL PRADESH			DISTRICT: SUBANSIRI LOWER
# STATE: ARUNACHAL PRADESH			DISTRICT: SUBANSIRI UPPER
# STATE: ARUNACHAL PRADESH			DISTRICT: TAWANG
# STATE: ARUNACHAL PRADESH			DISTRICT: TIRAP
# STATE: ASSAM			DISTRICT: BARPETA
# STATE: ASSAM			DISTRICT: BONGAIGAON
# STATE: ASSAM			DISTRICT: C.I.D.
# STATE: ASSAM			DISTRICT: CACHAR
# STATE: ASSAM			DISTRICT: DARRANG
# STATE: ASSAM			DISTRICT: DHEMAJI
# STATE: ASSAM			DISTRICT: DHUBRI
# STATE: ASSAM			DISTRICT: DIBRUGARH
# STATE: ASSAM			DISTRICT: G.R.P.
# STATE: HIMACHAL PRADESH			DISTRICT: G.R.P.
# STATE: RAJASTHAN			DISTRICT: G.R.P.
# STATE: UTTAR PRADESH			DISTRICT: G.R.P.
# STATE: ASSAM			DISTRICT: GOALPARA
# STATE: ASSAM			DISTRICT: GOLAGHAT
# STATE: ASSAM			DISTRICT: GUWAHATI CITY
# STATE: ASSAM			DISTRICT: HAILAKANDI
# STATE: ASSAM			DISTRICT: JORHAT
# STATE: ASSAM			DISTRICT: KAMRUP
# STATE: ASSAM			DISTRICT: KARBI ANGLONG
# STATE: ASSAM			DISTRICT: KARIMGANJ
# STATE: ASSAM			DISTRICT: KOKRAJHAR
# STATE: ASSAM			DISTRICT: LAKHIMPUR
# STATE: ASSAM			DISTRICT: MORIGAON
# STATE: ASSAM			DISTRICT: N.C.HILLS
# STATE: ASSAM			DISTRICT: NAGAON
# STATE: ASSAM			DISTRICT: NALBARI
# STATE: ASSAM			DISTRICT: R.P.O.
# STATE: ASSAM			DISTRICT: SIBSAGAR
# STATE: ASSAM			DISTRICT: SONITPUR
# STATE: ASSAM			DISTRICT: TINSUKIA
# STATE: BIHAR			DISTRICT: ARARIA
# STATE: BIHAR			DISTRICT: ARWAL
# STATE: BIHAR			DISTRICT: BAGAHA
# STATE: BIHAR			DISTRICT: BANKA
# STATE: BIHAR			DISTRICT: BEGUSARAI
# STATE: BIHAR			DISTRICT: BETTIAH
# STATE: BIHAR			DISTRICT: BHABHUA
# STATE: BIHAR			DISTRICT: BHAGALPUR
# STATE: BIHAR			DISTRICT: BUXAR
# STATE: BIHAR			DISTRICT: GOPALGANJ
# STATE: BIHAR			DISTRICT: JAMALPUR RLY.
# STATE: BIHAR			DISTRICT: JAMUI
# STATE: BIHAR			DISTRICT: KATIHAR
# STATE: BIHAR			DISTRICT: KATIHAR RLY.
# STATE: BIHAR			DISTRICT: KHAGARIA
# STATE: BIHAR			DISTRICT: KISHANGANJ
# STATE: BIHAR			DISTRICT: LAKHISARAI
# STATE: BIHAR			DISTRICT: MADHEPURA
# STATE: GUJARAT			DISTRICT: PATAN
# STATE: GUJARAT			DISTRICT: PORBANDAR
# STATE: GUJARAT			DISTRICT: RAJKOT COMMR.
# STATE: GUJARAT			DISTRICT: RAJKOT RURAL
# STATE: GUJARAT			DISTRICT: SURAT COMMR.
# STATE: GUJARAT			DISTRICT: SURAT RURAL
# STATE: GUJARAT			DISTRICT: SURENDRANAGAR
# STATE: GUJARAT			DISTRICT: VADODARA COMMR.
# STATE: GUJARAT			DISTRICT: VADODARA RURAL
# STATE: GUJARAT			DISTRICT: VALSAD
# STATE: GUJARAT			DISTRICT: W.RLY
# STATE: HARYANA			DISTRICT: AMBALA
# STATE: HARYANA			DISTRICT: FARIDABAD
# STATE: HARYANA			DISTRICT: FATEHABAD
# STATE: HARYANA			DISTRICT: GRP
# STATE: HARYANA			DISTRICT: GURGAON
# STATE: HARYANA			DISTRICT: JHAJJAR
# STATE: HARYANA			DISTRICT: JIND
# STATE: HARYANA			DISTRICT: KAITHAL
# STATE: HARYANA			DISTRICT: KARNAL
# STATE: HARYANA			DISTRICT: KURUKSHETRA
# STATE: HARYANA			DISTRICT: MAHENDRAGARH
# STATE: HARYANA			DISTRICT: PANCHKULA
# STATE: HARYANA			DISTRICT: PANIPAT
# STATE: HARYANA			DISTRICT: REWARI
# STATE: HARYANA			DISTRICT: ROHTAK
# STATE: HARYANA			DISTRICT: SIRSA
# STATE: HARYANA			DISTRICT: SONIPAT
# STATE: HARYANA			DISTRICT: YAMUNANAGAR
# STATE: HIMACHAL PRADESH			DISTRICT: CHAMBA
# STATE: HIMACHAL PRADESH			DISTRICT: HAMIRPUR
# STATE: UTTAR PRADESH			DISTRICT: HAMIRPUR
# STATE: HIMACHAL PRADESH			DISTRICT: KANGRA
# STATE: HIMACHAL PRADESH			DISTRICT: KINNAUR
# STATE: HIMACHAL PRADESH			DISTRICT: KULLU
# STATE: HIMACHAL PRADESH			DISTRICT: LAHAUL-SPITI
# STATE: HIMACHAL PRADESH			DISTRICT: MANDI
# STATE: HIMACHAL PRADESH			DISTRICT: SHIMLA
# STATE: HIMACHAL PRADESH			DISTRICT: SIRMAUR
# STATE: HIMACHAL PRADESH			DISTRICT: SOLAN
# STATE: HIMACHAL PRADESH			DISTRICT: UNA
# STATE: JAMMU & KASHMIR			DISTRICT: ANANTNAG
# STATE: JAMMU & KASHMIR			DISTRICT: AWANTIPORA
# STATE: JAMMU & KASHMIR			DISTRICT: BARAMULLA
# STATE: JAMMU & KASHMIR			DISTRICT: BORDER
# STATE: JAMMU & KASHMIR			DISTRICT: BUDGAM
# STATE: JAMMU & KASHMIR			DISTRICT: CRIME JAMMU
# STATE: JAMMU & KASHMIR			DISTRICT: CRIME SRINAGAR
# STATE: JAMMU & KASHMIR			DISTRICT: DODA
# STATE: JAMMU & KASHMIR			DISTRICT: GANDERBAL
# STATE: JAMMU & KASHMIR			DISTRICT: JAMMU
# STATE: JAMMU & KASHMIR			DISTRICT: KARGIL
# STATE: JAMMU & KASHMIR			DISTRICT: KATHUA
# STATE: JAMMU & KASHMIR			DISTRICT: KULGAM
# STATE: JAMMU & KASHMIR			DISTRICT: KUPWARA
# STATE: JAMMU & KASHMIR			DISTRICT: LEH
# STATE: JAMMU & KASHMIR			DISTRICT: POONCH
# STATE: JAMMU & KASHMIR			DISTRICT: PULWAMA
# STATE: JAMMU & KASHMIR			DISTRICT: RAILWAYS
# STATE: KARNATAKA			DISTRICT: RAILWAYS
# STATE: KERALA			DISTRICT: RAILWAYS
# STATE: JAMMU & KASHMIR			DISTRICT: RAJOURI
# STATE: JAMMU & KASHMIR			DISTRICT: RAMBAN
# STATE: JAMMU & KASHMIR			DISTRICT: REASI
# STATE: JAMMU & KASHMIR			DISTRICT: SRINAGAR
# STATE: JAMMU & KASHMIR			DISTRICT: UDHAMPUR
# STATE: JHARKHAND			DISTRICT: CHAIBASA
# STATE: JHARKHAND			DISTRICT: CHATRA
# STATE: JHARKHAND			DISTRICT: DEOGHAR
# STATE: JHARKHAND			DISTRICT: DHANBAD RLY.
# STATE: JHARKHAND			DISTRICT: DUMKA
# STATE: JHARKHAND			DISTRICT: GARHWA
# STATE: JHARKHAND			DISTRICT: GODDA
# STATE: JHARKHAND			DISTRICT: GUMLA
# STATE: JHARKHAND			DISTRICT: JAMSHEDPUR
# STATE: JHARKHAND			DISTRICT: JAMSHEDPUR RLY.
# STATE: JHARKHAND			DISTRICT: JAMTARA
# STATE: JHARKHAND			DISTRICT: KODERMA
# STATE: JHARKHAND			DISTRICT: LATEHAR
# STATE: JHARKHAND			DISTRICT: LOHARDAGGA
# STATE: JHARKHAND			DISTRICT: PAKUR
# STATE: JHARKHAND			DISTRICT: PALAMU
# STATE: JHARKHAND			DISTRICT: RANCHI
# STATE: JHARKHAND			DISTRICT: SAHEBGANJ
# STATE: JHARKHAND			DISTRICT: SARAIKELA
# STATE: JHARKHAND			DISTRICT: SIMDEGA
# STATE: KARNATAKA			DISTRICT: BAGALKOT
# STATE: KARNATAKA			DISTRICT: BELGAUM
# STATE: KARNATAKA			DISTRICT: BELLARY
# STATE: KARNATAKA			DISTRICT: BIDAR
# STATE: KARNATAKA			DISTRICT: BIJAPUR
# STATE: KARNATAKA			DISTRICT: CHAMARAJNAGAR
# STATE: KARNATAKA			DISTRICT: CHICKMAGALUR
# STATE: KARNATAKA			DISTRICT: CHITRADURGA
# STATE: KARNATAKA			DISTRICT: DAKSHIN KANNADA
# STATE: KARNATAKA			DISTRICT: DAVANAGERE
# STATE: KARNATAKA			DISTRICT: DHARWAD COMMR.
# STATE: KARNATAKA			DISTRICT: DHARWAD RURAL
# STATE: KARNATAKA			DISTRICT: GADAG
# STATE: KARNATAKA			DISTRICT: GULBARGA
# STATE: KARNATAKA			DISTRICT: HASSAN
# STATE: KARNATAKA			DISTRICT: HAVERI
# STATE: KARNATAKA			DISTRICT: K.G.F.
# STATE: KARNATAKA			DISTRICT: KODAGU
# STATE: KARNATAKA			DISTRICT: KOLAR
# STATE: KARNATAKA			DISTRICT: KOPPAL
# STATE: KARNATAKA			DISTRICT: MANDYA
# STATE: KARNATAKA			DISTRICT: MYSORE COMMR.
# STATE: KARNATAKA			DISTRICT: MYSORE RURAL
# STATE: KARNATAKA			DISTRICT: RAICHUR
# STATE: KARNATAKA			DISTRICT: SHIMOGA
# STATE: KARNATAKA			DISTRICT: UDUPI
# STATE: KARNATAKA			DISTRICT: UTTAR KANNADA
# STATE: KERALA			DISTRICT: ALAPUZHA
# STATE: KERALA			DISTRICT: CBCID
# STATE: KERALA			DISTRICT: ERNAKULAM
# STATE: KERALA			DISTRICT: IDUKKI
# STATE: KERALA			DISTRICT: KANNUR
# STATE: KERALA			DISTRICT: KASARGOD
# STATE: KERALA			DISTRICT: KOLLAM
# STATE: KERALA			DISTRICT: KOTTAYAM
# STATE: KERALA			DISTRICT: KOZHIKODE
# STATE: KERALA			DISTRICT: MALAPPURAM
# STATE: KERALA			DISTRICT: PALAKKAD
# STATE: KERALA			DISTRICT: PATHANAMTHITTA
# STATE: KERALA			DISTRICT: THRISSUR
# STATE: KERALA			DISTRICT: TRIVANDRUM
# STATE: KERALA			DISTRICT: WAYANADU
# STATE: MADHYA PRADESH			DISTRICT: BALAGHAT
# STATE: MADHYA PRADESH			DISTRICT: BARWANI
# STATE: MADHYA PRADESH			DISTRICT: BETUL
# STATE: MADHYA PRADESH			DISTRICT: BHOPAL
# STATE: MADHYA PRADESH			DISTRICT: BHOPAL RLY.
# STATE: MADHYA PRADESH			DISTRICT: CHHATARPUR
# STATE: MADHYA PRADESH			DISTRICT: CHHINDWARA
# STATE: MADHYA PRADESH			DISTRICT: DATIYA
# STATE: MADHYA PRADESH			DISTRICT: DEWAS
# STATE: MADHYA PRADESH			DISTRICT: DINDORI
# STATE: MADHYA PRADESH			DISTRICT: GUNA
# STATE: MADHYA PRADESH			DISTRICT: GWALIOR
# STATE: MADHYA PRADESH			DISTRICT: HARDA
# STATE: MADHYA PRADESH			DISTRICT: HOSHANGABAD
# STATE: MADHYA PRADESH			DISTRICT: INDORE RLY.
# STATE: MADHYA PRADESH			DISTRICT: JABALPUR RLY.
# STATE: MADHYA PRADESH			DISTRICT: JHABUA
# STATE: MADHYA PRADESH			DISTRICT: KATNI
# STATE: MADHYA PRADESH			DISTRICT: KHANDWA
# STATE: MADHYA PRADESH			DISTRICT: KHARGON
# STATE: MADHYA PRADESH			DISTRICT: MANDLA
# STATE: MADHYA PRADESH			DISTRICT: MANDSAUR
# STATE: MADHYA PRADESH			DISTRICT: NARSINGHPUR
# STATE: MADHYA PRADESH			DISTRICT: NEEMUCH
# STATE: MADHYA PRADESH			DISTRICT: PANNA
# STATE: MADHYA PRADESH			DISTRICT: RAISEN
# STATE: MADHYA PRADESH			DISTRICT: RAJGARH
# STATE: MADHYA PRADESH			DISTRICT: RATLAM
# STATE: MADHYA PRADESH			DISTRICT: REWA
# STATE: MADHYA PRADESH			DISTRICT: SATNA
# STATE: MADHYA PRADESH			DISTRICT: SEONI
# STATE: MADHYA PRADESH			DISTRICT: SHAHDOL
# STATE: MADHYA PRADESH			DISTRICT: SHAJAPUR
# STATE: MADHYA PRADESH			DISTRICT: SHEOPUR
# STATE: MANIPUR			DISTRICT: CHANDEL
# STATE: MANIPUR			DISTRICT: CHURACHANDPUR
# STATE: MANIPUR			DISTRICT: IMPHAL(EAST)
# STATE: MANIPUR			DISTRICT: IMPHAL(WEST)
# STATE: MANIPUR			DISTRICT: SENAPATI
# STATE: MANIPUR			DISTRICT: TAMENGLONG
# STATE: MANIPUR			DISTRICT: THOUBAL
# STATE: MANIPUR			DISTRICT: UKHRUL
# STATE: MEGHALAYA			DISTRICT: GARO HILLS EAST
# STATE: MEGHALAYA			DISTRICT: GARO HILLS SOUTH
# STATE: MEGHALAYA			DISTRICT: GARO HILLS WEST
# STATE: MEGHALAYA			DISTRICT: JAINTIA HILLS
# STATE: MEGHALAYA			DISTRICT: KHASI HILLS EAST
# STATE: MEGHALAYA			DISTRICT: KHASI HILLS WEST
# STATE: MEGHALAYA			DISTRICT: RI-BHOI
# STATE: MIZORAM			DISTRICT: AIZAWL
# STATE: MIZORAM			DISTRICT: CHAMPHAI
# STATE: MIZORAM			DISTRICT: KOLASIB
# STATE: MIZORAM			DISTRICT: LAWNGTLAI
# STATE: MIZORAM			DISTRICT: LUNGLEI
# STATE: MIZORAM			DISTRICT: MAMIT
# STATE: MIZORAM			DISTRICT: SAIHA
# STATE: MIZORAM			DISTRICT: SERCHHIP
# STATE: NAGALAND			DISTRICT: DIMAPUR
# STATE: NAGALAND			DISTRICT: KIPHIRE
# STATE: NAGALAND			DISTRICT: KOHIMA
# STATE: NAGALAND			DISTRICT: MOKOKCHUNG
# STATE: NAGALAND			DISTRICT: MON
# STATE: NAGALAND			DISTRICT: PEREN
# STATE: NAGALAND			DISTRICT: PHEK
# STATE: NAGALAND			DISTRICT: TUENSANG
# STATE: NAGALAND			DISTRICT: WOKHA
# STATE: NAGALAND			DISTRICT: ZUNHEBOTO
# STATE: ODISHA			DISTRICT: ANGUL
# STATE: ODISHA			DISTRICT: BARAGARH
# STATE: ODISHA			DISTRICT: BERHAMPUR
# STATE: ODISHA			DISTRICT: BOLANGIR
# STATE: ODISHA			DISTRICT: BOUDH
# STATE: ODISHA			DISTRICT: DEOGARH
# STATE: ODISHA			DISTRICT: DHENKANAL
# STATE: ODISHA			DISTRICT: GAJAPATI
# STATE: ODISHA			DISTRICT: GANJAM
# STATE: ODISHA			DISTRICT: JAGATSINGHPUR
# STATE: ODISHA			DISTRICT: JAJPUR
# STATE: ODISHA			DISTRICT: JHARSUGUDA
# STATE: ODISHA			DISTRICT: KALAHANDI
# STATE: ODISHA			DISTRICT: KANDHAMAL
# STATE: ODISHA			DISTRICT: KEONJHAR
# STATE: ODISHA			DISTRICT: KHURDA
# STATE: ODISHA			DISTRICT: KORAPUT
# STATE: ODISHA			DISTRICT: MALKANGIR
# STATE: ODISHA			DISTRICT: MAYURBHANJ
# STATE: ODISHA			DISTRICT: NAYAGARH
# STATE: ODISHA			DISTRICT: NOWRANGPUR
# STATE: ODISHA			DISTRICT: NUAPADA
# STATE: ODISHA			DISTRICT: RAYAGADA
# STATE: ODISHA			DISTRICT: ROURKELA
# STATE: RAJASTHAN			DISTRICT: TONK
# STATE: RAJASTHAN			DISTRICT: UDAIPUR
# STATE: SIKKIM			DISTRICT: EAST
# STATE: DELHI			DISTRICT: EAST
# STATE: SIKKIM			DISTRICT: NORTH
# STATE: TRIPURA			DISTRICT: NORTH
# STATE: DELHI			DISTRICT: NORTH
# STATE: SIKKIM			DISTRICT: SOUTH
# STATE: TRIPURA			DISTRICT: SOUTH
# STATE: DELHI			DISTRICT: SOUTH
# STATE: SIKKIM			DISTRICT: WEST
# STATE: TRIPURA			DISTRICT: WEST
# STATE: DELHI			DISTRICT: WEST
# STATE: TAMIL NADU			DISTRICT: ARIYALUR
# STATE: TAMIL NADU			DISTRICT: CHENGAI
# STATE: TAMIL NADU			DISTRICT: CHENNAI
# STATE: TAMIL NADU			DISTRICT: CHENNAI RLY.
# STATE: TAMIL NADU			DISTRICT: COIMBATORE RURAL
# STATE: TAMIL NADU			DISTRICT: COIMBATORE URBAN
# STATE: TAMIL NADU			DISTRICT: CUDDALORE
# STATE: TAMIL NADU			DISTRICT: DHARMAPURI
# STATE: TAMIL NADU			DISTRICT: DINDIGUL
# STATE: TAMIL NADU			DISTRICT: ERODE
# STATE: TAMIL NADU			DISTRICT: KANCHIPURAM
# STATE: TAMIL NADU			DISTRICT: KANYAKUMARI
# STATE: TAMIL NADU			DISTRICT: KARUR
# STATE: TAMIL NADU			DISTRICT: MADURAI RURAL
# STATE: TAMIL NADU			DISTRICT: MADURAI URBAN
# STATE: TAMIL NADU			DISTRICT: NAGAPATTINAM
# STATE: TAMIL NADU			DISTRICT: NAMAKKAL
# STATE: TAMIL NADU			DISTRICT: NILGIRIS
# STATE: TAMIL NADU			DISTRICT: PERAMBALUR
# STATE: TAMIL NADU			DISTRICT: PUDUKOTTAI
# STATE: TAMIL NADU			DISTRICT: RAMNATHAPURAM
# STATE: TAMIL NADU			DISTRICT: SALEM RURAL
# STATE: TAMIL NADU			DISTRICT: SALEM URBAN
# STATE: TAMIL NADU			DISTRICT: SIVAGANGAI
# STATE: TAMIL NADU			DISTRICT: THANJAVUR
# STATE: TAMIL NADU			DISTRICT: THENI
# STATE: TAMIL NADU			DISTRICT: THIRUNELVELI RURAL
# STATE: TAMIL NADU			DISTRICT: THIRUNELVELI URBAN
# STATE: TAMIL NADU			DISTRICT: THIRUVALLUR
# STATE: TAMIL NADU			DISTRICT: THIRUVANNAMALAI
# STATE: TAMIL NADU			DISTRICT: THIRUVARUR
# STATE: TAMIL NADU			DISTRICT: THOOTHUGUDI
# STATE: TAMIL NADU			DISTRICT: TRICHY RLY.
# STATE: TAMIL NADU			DISTRICT: TRICHY RURAL
# STATE: TAMIL NADU			DISTRICT: TRICHY URBAN
# STATE: TAMIL NADU			DISTRICT: VELLORE
# STATE: TAMIL NADU			DISTRICT: VILLUPURAM
# STATE: TAMIL NADU			DISTRICT: VIRUDHUNAGAR
# STATE: TRIPURA			DISTRICT: DHALAI
# STATE: UTTAR PRADESH			DISTRICT: AMBEDKAR NAGAR
# STATE: UTTAR PRADESH			DISTRICT: AURAIYA
# STATE: UTTAR PRADESH			DISTRICT: BAGHPAT
# STATE: UTTAR PRADESH			DISTRICT: BAHRAICH
# STATE: UTTAR PRADESH			DISTRICT: BALLIA
# STATE: UTTAR PRADESH			DISTRICT: BANDA
# STATE: UTTAR PRADESH			DISTRICT: BASTI
# STATE: UTTAR PRADESH			DISTRICT: CHANDOLI
# STATE: UTTAR PRADESH			DISTRICT: CHITRAKOOT DHAM
# STATE: UTTAR PRADESH			DISTRICT: FAIZABAD
# STATE: UTTAR PRADESH			DISTRICT: FATEHGARH
# STATE: UTTAR PRADESH			DISTRICT: GAUTAMBUDH NAGAR
# STATE: UTTAR PRADESH			DISTRICT: GHAZIPUR
# STATE: UTTAR PRADESH			DISTRICT: GORAKHPUR
# STATE: UTTAR PRADESH			DISTRICT: J.P.NAGAR
# STATE: UTTAR PRADESH			DISTRICT: KANNAUJ
# STATE: UTTAR PRADESH			DISTRICT: KUSHI NAGAR
# STATE: UTTAR PRADESH			DISTRICT: LALITPUR
# STATE: UTTAR PRADESH			DISTRICT: MAHARAJGANJ
# STATE: UTTAR PRADESH			DISTRICT: MAHOBA
# STATE: UTTAR PRADESH			DISTRICT: MATHURA
# STATE: UTTAR PRADESH			DISTRICT: MAU
# STATE: UTTAR PRADESH			DISTRICT: RAMPUR
# STATE: UTTAR PRADESH			DISTRICT: SAHARANPUR
# STATE: UTTAR PRADESH			DISTRICT: SANT KABIRNAGAR
# STATE: UTTAR PRADESH			DISTRICT: SHRAWASTI
# STATE: UTTAR PRADESH			DISTRICT: SIDHARTHNAGAR
# STATE: UTTAR PRADESH			DISTRICT: SONBHADRA
# STATE: UTTAR PRADESH			DISTRICT: ST.RAVIDASNAGAR
# STATE: UTTARAKHAND			DISTRICT: ALMORA
# STATE: UTTARAKHAND			DISTRICT: BAGESHWAR
# STATE: UTTARAKHAND			DISTRICT: CHAMOLI
# STATE: UTTARAKHAND			DISTRICT: CHAMPAWAT
# STATE: UTTARAKHAND			DISTRICT: DEHRADUN
# STATE: UTTARAKHAND			DISTRICT: HARIDWAR
# STATE: UTTARAKHAND			DISTRICT: NAINITAL
# STATE: UTTARAKHAND			DISTRICT: PAURI GARHWAL
# STATE: UTTARAKHAND			DISTRICT: PITHORAGARH
# STATE: UTTARAKHAND			DISTRICT: RUDRA PRAYAG
# STATE: UTTARAKHAND			DISTRICT: TEHRI GARHWAL
# STATE: UTTARAKHAND			DISTRICT: UDHAMSINGH NAGAR
# STATE: UTTARAKHAND			DISTRICT: UTTARKASHI
# STATE: WEST BENGAL			DISTRICT: ASANSOL
# STATE: WEST BENGAL			DISTRICT: BANKURA
# STATE: WEST BENGAL			DISTRICT: BIRBHUM
# STATE: WEST BENGAL			DISTRICT: COOCHBEHAR
# STATE: WEST BENGAL			DISTRICT: DAKSHIN DINAJPUR
# STATE: WEST BENGAL			DISTRICT: DARJEELING
# STATE: WEST BENGAL			DISTRICT: HOOGHLY
# STATE: WEST BENGAL			DISTRICT: HOWRAH
# STATE: WEST BENGAL			DISTRICT: HOWRAH CITY
# STATE: WEST BENGAL			DISTRICT: HOWRAH G.R.P.
# STATE: WEST BENGAL			DISTRICT: JALPAIGURI
# STATE: WEST BENGAL			DISTRICT: KOLKATA
# STATE: WEST BENGAL			DISTRICT: MALDA
# STATE: WEST BENGAL			DISTRICT: MURSHIDABAD
# STATE: WEST BENGAL			DISTRICT: NADIA
# STATE: WEST BENGAL			DISTRICT: PURULIA
# STATE: WEST BENGAL			DISTRICT: SEALDAH G.R.P.
# STATE: WEST BENGAL			DISTRICT: SILIGURI G.R.P.
# STATE: WEST BENGAL			DISTRICT: UTTAR DINAJPUR
# STATE: A & N ISLANDS			DISTRICT: ANDAMAN
# STATE: A & N ISLANDS			DISTRICT: NICOBAR
# STATE: CHANDIGARH			DISTRICT: CHANDIGARH
# STATE: D & N HAVELI			DISTRICT: D and N HAVELI
# STATE: DAMAN & DIU			DISTRICT: DAMAN
# STATE: DAMAN & DIU			DISTRICT: DIU
# STATE: DELHI			DISTRICT: CENTRAL
# STATE: DELHI			DISTRICT: G.R.P.(RLY)
# STATE: DELHI			DISTRICT: I.G.I. AIRPORT
# STATE: DELHI			DISTRICT: NEW DELHI
# STATE: DELHI			DISTRICT: NORTH EAST
# STATE: DELHI			DISTRICT: S.T.F.
# STATE: DELHI			DISTRICT: SOUTH WEST
# STATE: LAKSHADWEEP			DISTRICT: LAKSHADWEEP
# STATE: PUDUCHERRY			DISTRICT: PONDICHERRY

# %%
import folium
from folium.plugins import HeatMap
import sys
map_crime = folium.Map(location=[15.9129,79.7400], zoom_start=5,tiles="openstreetmap")
map_crime

hlat = []
hlon = []
for i in H_index:
    hlat.append(df.Latitude[i])
    hlon.append(df.Longitude[i])


popup_texts = []
for i in H_index:
    popup_text = """ District : {} <br>
                     State : {} <br> """
    popup_texts.append(str(popup_text.format(df["DISTRICT"][i], df["STATE/UT"][i])))
# print(popup_texts)

for i in range(len(H_index)):
#     print(popup_texts[i])
    folium.CircleMarker(location=[float(hlat[i]),float(hlon[i])],popup=popup_texts[i],color = 'red',fill =True).add_to(map_crime)

mlat = []
mlon = []

for i in M_index:
    mlat.append(df.Latitude[i])
    mlon.append(df.Longitude[i])
popup_texts = []
for i in M_index:
    popup_text = """ District : {} <br> State : {} <br> """
    popup_texts.append(str(popup_text.format(df["DISTRICT"][i], df["STATE/UT"][i])))
for i in range(len(M_index)):
    try:
#         print(popup_texts[i])
        folium.CircleMarker(location=[float(mlat[i]),float(mlon[i])],popup=popup_texts[i],color = 'green',fill =True).add_to(map_crime)  
    except:
        pass

llat = []
llon = []
for i in L_index:
    llat.append(df['Latitude'][i])
    llon.append(df['Longitude'][i])
popup_texts = []
for i in L_index:
    popup_text = """ District : {} <br> State : {} <br> """
    popup_texts.append(str(popup_text.format(df["DISTRICT"][i], df["STATE/UT"][i])))
for i in range(len(L_index)):
    try:
#         print(popup_texts[i])
        folium.CircleMarker(location=[float(llat[i]),float(llon[i])],popup=popup_texts[i],color = 'blue',fill =True).add_to(map_crime)  
    except:
        pass

# %%
map_crime
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
